# %% [markdown]
# <a href="https://colab.research.google.com/github/indahsasmita1907-art/StrukturDataD-pertemuan-1/blob/main/lATIHAN_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list = []

# %%
for i in range(10):
    angka = int(input("Masukkan angka: "))
    list.append(angka)
# Out:
# Masukkan angka: 1
# Masukkan angka: 2
# Masukkan angka: 3
# Masukkan angka: 45
# Masukkan angka: 67
# Masukkan angka: 43
# Masukkan angka: 92
# Masukkan angka: 23
# Masukkan angka: 22
# Masukkan angka: 45

# %%
print("List:", list)
print("Nilai maksimum:", max(list))
print("Nilai minimum:", min(list))
print("Rata-rata:", sum(list)/len(list))
# Out:
# List: [1, 2, 3, 45, 67, 43, 92, 23, 22, 45]
# Nilai maksimum: 92
# Nilai minimum: 1
# Rata-rata: 34.3

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(list)), list)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
